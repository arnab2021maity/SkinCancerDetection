# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization

# %%
df_raw = pd.read_excel('C:\\Users\\DELL\\Downloads\\GSE7553.XLSX', sheet_name='Sheet1')
df_raw.head()
# Out:
#   !Sample_characteristics_ch1  Basal cell carcinoma  Basal cell carcinoma.1  \
# 0                   1007_s_at             3386.8800               6271.1300
# 1                     1053_at             1053.8600                771.8190
# 2                      117_at              417.2160                334.8500
# 3                      121_at              854.2090                720.3950
# 4                   1255_g_at               61.7639                 69.9469
#
#    Basal cell carcinoma.2  Basal cell carcinoma.3  Melanoma in situ  \
# 0               3467.4700               8058.2000         2645.9300
# 1                921.4700                961.1210         1138.0200
# 2                542.5670                374.7210          480.5960
# 3               1207.5500                810.1350          918.6500
# 4                 50.3568                 11.6666           19.1772
#
#    Melanoma in situ.1  Primary Melanoma  Primary Melanoma.1  \
# 0           3994.0500         2732.5100           2765.6200
# 1            863.7390          887.5550            971.2790
# 2            240.3580          471.4690            254.7410
# 3            800.3820          721.6720            871.8210
# 4             65.9618           70.8433             28.5029
#
#    Metastatic Melanoma  ...  Metastatic Melanoma.36  Metastatic Melanoma.37  \
# 0            2077.9700  ...               2876.6000               3942.1500
# 1            2117.9100  ...                724.4620               1520.6400
# 2             278.7100  ...                612.8740                660.2980
# 3             839.0940  ...               1551.5900               1538.7400
# 4              59.8483  ...                 70.7679                 17.1508
#
#    Metastatic Melanoma.38  Metastatic Melanoma.39  \
# 0               1844.1700               2431.2200
# 1               1207.4600                747.5530
# 2                576.5840               1012.7900
# 3               1451.3500               2009.5300
# 4                 46.1233                 24.2953
#
#    normal human epidermal melanocytes  Normal Skin.1  Normal Skin.2  \
# 0                           2272.5300      4571.5200      5141.0900
# 1                           1403.6200      1019.4700       717.3900
# 2                            321.4090       319.7780       351.6650
# 3                           1964.1000      2036.5500      1734.0500
# 4                             65.9724        17.7486        30.4646
#
#    Normal Skin.3  Primary Melanoma.12  Primary Melanoma.13
# 0      4230.8000            2998.2700             6346.580
# 1       590.0390             995.2780             2000.600
# 2       362.5880            1323.6900              569.504
# 3      1692.0800            1748.4900             4519.840
# 4        58.7975              33.8397              113.995
#
# [5 rows x 88 columns]

# %%
print("Checking missing values:")
print(df_raw.isnull().sum())
# Out:
# Checking missing values:
# !Sample_characteristics_ch1    0
# Basal cell carcinoma           0
# Basal cell carcinoma.1         0
# Basal cell carcinoma.2         0
# Basal cell carcinoma.3         0
#                               ..
# Normal Skin.1                  0
# Normal Skin.2                  0
# Normal Skin.3                  0
# Primary Melanoma.12            0
# Primary Melanoma.13            0
# Length: 88, dtype: int64

# %%
df_raw = df_raw.set_index(df_raw.columns[0])

# %%
sample_labels = df_raw.columns
y_raw = [label.split('.')[0] for label in sample_labels]

# %%
df_transposed = df_raw.transpose()

# %%
X = df_transposed.astype(float).values

# %%
print("Unique labels:", set(y_raw))
# Out:
# Unique labels: {'Normal Skin', 'Basal cell carcinoma', 'Metastatic Melanoma', 'Squamous cell carcinoma', 'Melanoma in situ', 'Primary Melanoma', 'normal human epidermal melanocytes'}

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y_raw)
y_encoded = to_categorical(y)
num_classes = len(encoder.classes_)

# %%
unique, counts = np.unique(y, return_counts=True)

for cls, count in zip(encoder.classes_, counts):
    print(f"  {cls}: {count} samples")

plt.figure(figsize=(10, 6))
plt.bar(encoder.classes_, counts, color='skyblue')
plt.title('Class Distribution (Cancer Types)')
plt.xlabel('Cancer Type')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#   Basal cell carcinoma: 15 samples
#   Melanoma in situ: 2 samples
#   Metastatic Melanoma: 40 samples
#   Normal Skin: 4 samples
#   Primary Melanoma: 14 samples
#   Squamous cell carcinoma: 11 samples
#   normal human epidermal melanocytes: 1 samples

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
print(X_train.shape)
# Out:
# (69, 54675)

# %%
model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# Save the model architecture as an image
plot_model(model, to_file='dense_model.png', show_shapes=True, show_layer_names=True)

# Display it in the notebook
Image(filename='dense_model.png')

# %%
checkpoint = ModelCheckpoint('best_gene_model.h5', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=8,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - ETA: 0s - loss: 2.3460 - accuracy: 0.3188
# Epoch 1: val_loss improved from inf to 6.44584, saving model to best_gene_model.h5
# 9/9 [==============================] - 4s 281ms/step - loss: 2.3460 - accuracy: 0.3188 - val_loss: 6.4458 - val_accuracy: 0.5000
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2283 - accuracy: 0.5942
# Epoch 2: val_loss improved from 6.44584 to 3.37611, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 223ms/step - loss: 1.2283 - accuracy: 0.5942 - val_loss: 3.3761 - val_accuracy: 0.6111
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 1.0416 - accuracy: 0.6522
# Epoch 3: val_loss improved from 3.37611 to 2.52172, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 187ms/step - loss: 1.0416 - accuracy: 0.6522 - val_loss: 2.5217 - val_accuracy: 0.6667
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 1.0765 - accuracy: 0.6957
# Epoch 4: val_loss improved from 2.52172 to 1.94050, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 181ms/step - loss: 1.0765 - accuracy: 0.6957 - val_loss: 1.9405 - val_accuracy: 0.7778
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 0.8903 - accuracy: 0.6957
# Epoch 5: val_loss improved from 1.94050 to 1.22407, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 263ms/step - loss: 0.8903 - accuracy: 0.6957 - val_loss: 1.2241 - val_accuracy: 0.7778
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 1.1843 - accuracy: 0.6667
# Epoch 6: val_loss improved from 1.22407 to 1.01425, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 188ms/step - loss: 1.1843 - accuracy: 0.6667 - val_loss: 1.0143 - val_accuracy: 0.8889
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5716 - accuracy: 0.8116
# Epoch 7: val_loss improved from 1.01425 to 0.96716, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 182ms/step - loss: 0.5716 - accuracy: 0.8116 - val_loss: 0.9672 - val_accuracy: 0.8333
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 0.8486 - accuracy: 0.7681
# Epoch 8: val_loss improved from 0.96716 to 0.77178, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 194ms/step - loss: 0.8486 - accuracy: 0.7681 - val_loss: 0.7718 - val_accuracy: 0.8333
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5290 - accuracy: 0.8116
# Epoch 9: val_loss improved from 0.77178 to 0.71151, saving model to best_gene_model.h5
# 9/9 [==============================] - 6s 774ms/step - loss: 0.5290 - accuracy: 0.8116 - val_loss: 0.7115 - val_accuracy: 0.8333
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5787 - accuracy: 0.7971
# Epoch 10: val_loss improved from 0.71151 to 0.57221, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 194ms/step - loss: 0.5787 - accuracy: 0.7971 - val_loss: 0.5722 - val_accuracy: 0.8889
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.8551
# Epoch 11: val_loss improved from 0.57221 to 0.41855, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 299ms/step - loss: 0.3836 - accuracy: 0.8551 - val_loss: 0.4186 - val_accuracy: 0.8889
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 0.4606 - accuracy: 0.8551
# Epoch 12: val_loss improved from 0.41855 to 0.40715, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 282ms/step - loss: 0.4606 - accuracy: 0.8551 - val_loss: 0.4071 - val_accuracy: 0.8889
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5769 - accuracy: 0.8116
# Epoch 13: val_loss did not improve from 0.40715
# 9/9 [==============================] - 1s 95ms/step - loss: 0.5769 - accuracy: 0.8116 - val_loss: 0.4322 - val_accuracy: 0.8889
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5825 - accuracy: 0.8261
# Epoch 14: val_loss did not improve from 0.40715
# 9/9 [==============================] - 1s 99ms/step - loss: 0.5825 - accuracy: 0.8261 - val_loss: 0.5099 - val_accuracy: 0.8889
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.9275
# Epoch 15: val_loss did not improve from 0.40715
# 9/9 [==============================] - 1s 98ms/step - loss: 0.2989 - accuracy: 0.9275 - val_loss: 0.5369 - val_accuracy: 0.8889
# Epoch 16/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.9130
# Epoch 16: val_loss did not improve from 0.40715
# 9/9 [==============================] - 1s 104ms/step - loss: 0.2787 - accuracy: 0.9130 - val_loss: 0.6064 - val_accuracy: 0.8889
# Epoch 17/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.8841
# Epoch 17: val_loss did not improve from 0.40715
# 9/9 [==============================] - 1s 120ms/step - loss: 0.3721 - accuracy: 0.8841 - val_loss: 0.4900 - val_accuracy: 0.9444
# Epoch 18/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3407 - accuracy: 0.8986
# Epoch 18: val_loss did not improve from 0.40715
# 9/9 [==============================] - 1s 101ms/step - loss: 0.3407 - accuracy: 0.8986 - val_loss: 0.4633 - val_accuracy: 0.8889
# Epoch 19/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3951 - accuracy: 0.8551
# Epoch 19: val_loss improved from 0.40715 to 0.40376, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 292ms/step - loss: 0.3951 - accuracy: 0.8551 - val_loss: 0.4038 - val_accuracy: 0.8889
# Epoch 20/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.40376 to 0.35379, saving model to best_gene_model.h5
# 9/9 [==============================] - 2s 287ms/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 0.3538 - val_accuracy: 0.9444
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9710
# Epoch 21: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 102ms/step - loss: 0.1693 - accuracy: 0.9710 - val_loss: 0.3552 - val_accuracy: 0.9444
# Epoch 22/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.9420
# Epoch 22: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 101ms/step - loss: 0.2634 - accuracy: 0.9420 - val_loss: 0.4951 - val_accuracy: 0.9444
# Epoch 23/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8986
# Epoch 23: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 97ms/step - loss: 0.3553 - accuracy: 0.8986 - val_loss: 0.5384 - val_accuracy: 0.8889
# Epoch 24/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9710
# Epoch 24: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 129ms/step - loss: 0.1244 - accuracy: 0.9710 - val_loss: 0.5404 - val_accuracy: 0.8889
# Epoch 25/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9565
# Epoch 25: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 115ms/step - loss: 0.1420 - accuracy: 0.9565 - val_loss: 0.5284 - val_accuracy: 0.8889
# Epoch 26/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9130
# Epoch 26: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 102ms/step - loss: 0.2193 - accuracy: 0.9130 - val_loss: 0.5696 - val_accuracy: 0.8333
# Epoch 27/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9565
# Epoch 27: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 110ms/step - loss: 0.0973 - accuracy: 0.9565 - val_loss: 0.5409 - val_accuracy: 0.8333
# Epoch 28/50
# 9/9 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.8841
# Epoch 28: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 110ms/step - loss: 0.4271 - accuracy: 0.8841 - val_loss: 0.5143 - val_accuracy: 0.8333
# Epoch 29/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9855
# Epoch 29: val_loss did not improve from 0.35379
# 9/9 [==============================] - 1s 109ms/step - loss: 0.0899 - accuracy: 0.9855 - val_loss: 0.5143 - val_accuracy: 0.8333
# Epoch 30/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9565
# Epoch 30: val_loss did not improve from 0.35379
# Restoring model weights from the end of the best epoch: 20.
# 9/9 [==============================] - 1s 119ms/step - loss: 0.0796 - accuracy: 0.9565 - val_loss: 0.4913 - val_accuracy: 0.8333
# Epoch 30: early stopping

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
df_test = pd.read_excel('C:\\Users\\DELL\\Downloads\\GSE7553.XLSX', sheet_name='Sheet1', index_col=0)
df_test = df_test.loc[df_raw.index]

# %%
X_test = df_test.transpose().astype(float).values
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled = scaler.transform(X) 
y_test = y_encoded

# %%
print("\n--- Predict One Sample at a Time ---")
print("Available sample indices: 0 to", X_test_scaled.shape[0] - 1)
print("Enter 'exit' to quit.\n")

while True:
    user_input = input("Enter sample number to predict (e.g., 0): ")
    if user_input.lower() == 'exit':
        print("Exiting prediction loop.")
        break
    if not user_input.isdigit():
        print("Invalid input. Please enter a number.")
        continue
    index = int(user_input)
    if index < 0 or index >= X_test_scaled.shape[0]:
        print(f"Index out of range. Please enter 0 to {X_test_scaled.shape[0] - 1}.")
        continue

    sample = X_test_scaled[index:index+1]
    print(sample)
    pred_prob = model.predict(sample, verbose=0)
    pred_class = np.argmax(pred_prob)
    pred_label = encoder.inverse_transform([pred_class])[0]
    confidence = pred_prob[0][pred_class]  

    true_class = np.argmax(y_test[index])
    true_label = encoder.inverse_transform([true_class])[0]


    print(f"Predicted label: {pred_label} (Confidence: {confidence:.2f})")
    print(f"Actual label: {true_label}")
    print(f"Sample {index}: Predicted Cancer Type -> {pred_label}\n")
# Out:
# --- Predict One Sample at a Time ---
# Available sample indices: 0 to 86
# Enter 'exit' to quit.
#
# Enter sample number to predict (e.g., 0): 1
# [[ 1.09287811 -0.33366778 -0.37457421 ...  0.18624519 -0.96168556
#   -0.52153792]]
# Predicted label: Basal cell carcinoma (Confidence: 1.00)
# Actual label: Basal cell carcinoma
# Sample 1: Predicted Cancer Type -> Basal cell carcinoma
#
# Enter sample number to predict (e.g., 0): 2
# [[-0.20250285 -0.08828173 -0.14451451 ...  0.80028669 -0.26891932
#   -0.89844191]]
# Predicted label: Basal cell carcinoma (Confidence: 1.00)
# Actual label: Basal cell carcinoma
# Sample 2: Predicted Cancer Type -> Basal cell carcinoma
#
# Enter sample number to predict (e.g., 0): 3
# [[ 1.91856184 -0.0232651  -0.33041456 ... -0.55053552 -0.89790382
#   -0.60736356]]
# Predicted label: Basal cell carcinoma (Confidence: 1.00)
# Actual label: Basal cell carcinoma
# Sample 3: Predicted Cancer Type -> Basal cell carcinoma
#
# Enter sample number to predict (e.g., 0): 5
# [[ 0.04079402 -0.18294452 -0.47923007 ...  3.20229812 -0.20651497
#   -0.26854758]]
# Predicted label: Melanoma in situ (Confidence: 1.00)
# Actual label: Melanoma in situ
# Sample 5: Predicted Cancer Type -> Melanoma in situ
#
# Enter sample number to predict (e.g., 0): 6
# [[-0.54207797 -0.1438929  -0.22326004 ... -0.73276342 -0.66029672
#   -0.82135874]]
# Predicted label: Primary Melanoma (Confidence: 1.00)
# Actual label: Primary Melanoma
# Sample 6: Predicted Cancer Type -> Primary Melanoma
#
# Enter sample number to predict (e.g., 0): 7
# [[-0.52678009 -0.00660881 -0.46329999 ... -0.71968498 -0.81294637
#   -0.17057488]]
# Predicted label: Primary Melanoma (Confidence: 1.00)
# Actual label: Primary Melanoma
# Sample 7: Predicted Cancer Type -> Primary Melanoma
#
# Enter sample number to predict (e.g., 0): 8
# [[-0.84449647  1.87354738 -0.43675281 ... -0.75141109  1.28074104
#    2.52272657]]
# Predicted label: Metastatic Melanoma (Confidence: 1.00)
# Actual label: Metastatic Melanoma
# Sample 8: Predicted Cancer Type -> Metastatic Melanoma
#
# Enter sample number to predict (e.g., 0): 16
# [[ 0.26370141 -0.64357853 -0.31292614 ... -0.00502295 -0.50123714
#   -0.57004168]]
# Predicted label: Normal Skin (Confidence: 0.99)
# Actual label: Normal Skin
# Sample 16: Predicted Cancer Type -> Normal Skin
#
# Enter sample number to predict (e.g., 0): 18
# [[-0.53576199  0.23369411 -0.36642698 ... -1.03701404  0.84179373
#   -0.40297025]]
# Predicted label: Squamous cell carcinoma (Confidence: 1.00)
# Actual label: Squamous cell carcinoma
# Sample 18: Predicted Cancer Type -> Squamous cell carcinoma
#
# Enter sample number to predict (e.g., 0): 23
# [[ 0.43452855 -0.22505586 -0.40679766 ... -0.90873457 -0.24255158
#   -0.81271617]]
# Predicted label: Basal cell carcinoma (Confidence: 0.99)
# Actual label: Basal cell carcinoma
# Sample 23: Predicted Cancer Type -> Basal cell carcinoma
#
# Enter sample number to predict (e.g., 0): exit
# Exiting prediction loop.
